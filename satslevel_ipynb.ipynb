# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import statsmodels
import patsy
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('cleancustomerbehaviourok.csv')
df
# Out:
#      Customer ID  Gender  Age           City  Membership Type  Total Spend  \
# 0            101       0   29       New York                2      1120.20
# 1            102       1   34    Los Angeles                0       780.50
# 2            103       0   43        Chicago                1       510.75
# 3            104       1   30  San Francisco                2      1480.30
# 4            105       1   27          Miami                0       720.40
# ..           ...     ...  ...            ...              ...          ...
# 345          446       1   32          Miami                0       660.30
# 346          447       0   36        Houston                1       470.50
# 347          448       0   30       New York                2      1190.80
# 348          449       1   34    Los Angeles                0       780.20
# 349          450       0   43        Chicago                1       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# 0                 14             4.6                 1
# 1                 11             4.1                 0
# 2                  9             3.4                 1
# 3                 19             4.7                 0
# 4                 13             4.0                 1
# ..               ...             ...               ...
# 345               10             3.8                 1
# 346                8             3.0                 0
# 347               16             4.5                 1
# 348               11             4.2                 0
# 349               10             3.3                 1
#
#      Days Since Last Purchase  Satisfaction Level  Spend per Item
# 0                          25                   2       80.014286
# 1                          18                   0       70.954545
# 2                          42                   0       56.750000
# 3                          12                   2       77.910526
# 4                          55                   0       55.415385
# ..                        ...                 ...             ...
# 345                        42                   0       66.030000
# 346                        27                   0       58.812500
# 347                        28                   2       74.425000
# 348                        21                   0       70.927273
# 349                        49                   0       51.575000
#
# [350 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    int64
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    int64
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    int64
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        350 non-null    int64
#  11  Spend per Item            350 non-null    float64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 32.9+ KB

# %% [markdown]
# # Pisahkan data X dan Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    int64
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    int64
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    int64
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        350 non-null    int64
#  11  Spend per Item            350 non-null    float64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 32.9+ KB

# %%
X = df[['Age', 'Items Purchased', 'Spend per Item', 'Average Rating', 'Discount Applied', 'Days Since Last Purchase']]
Y = df['Satisfaction Level']

# %%
print(X)
# Out:
#      Age  Items Purchased  Spend per Item  Average Rating  Discount Applied  \
# 0     29               14       80.014286             4.6                 1
# 1     34               11       70.954545             4.1                 0
# 2     43                9       56.750000             3.4                 1
# 3     30               19       77.910526             4.7                 0
# 4     27               13       55.415385             4.0                 1
# ..   ...              ...             ...             ...               ...
# 345   32               10       66.030000             3.8                 1
# 346   36                8       58.812500             3.0                 0
# 347   30               16       74.425000             4.5                 1
# 348   34               11       70.927273             4.2                 0
# 349   43               10       51.575000             3.3                 1
#
#      Days Since Last Purchase
# 0                          25
# 1                          18
# 2                          42
# 3                          12
# 4                          55
# ..                        ...
# 345                        42
# 346                        27
# 347                        28
# 348                        21
# 349                        49
#
# [350 rows x 6 columns]

# %%
print(Y)
# Out:
# 0      2
# 1      0
# 2      0
# 3      2
# 4      0
#       ..
# 345    0
# 346    0
# 347    2
# 348    0
# 349    0
# Name: Satisfaction Level, Length: 350, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X_train.shape,Y_train.shape,X_test.shape,Y_test.shape)
# Out:
# (280, 6) (280,) (70, 6) (70,)

# %% [markdown]
# # Membuat Model Random Forest Regressor

# %%
model = RandomForestRegressor(random_state=42, n_estimators=100)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# # Cek Akurasi Model

# %%
X_test
# Out:
#      Age  Items Purchased  Spend per Item  Average Rating  Discount Applied  \
# 157   35               12       67.575000             4.3                 0
# 341   31               15       76.040000             4.5                 1
# 315   27               13       54.646154             4.1                 1
# 234   33               13       63.903846             4.2                 0
# 155   37                7       61.542857             3.4                 0
# ..   ...              ...             ...             ...               ...
# 94    26               12       57.550000             3.9                 1
# 181   34               11       71.836364             4.0                 0
# 179   36                8       58.812500             3.0                 0
# 199   34               11       72.745455             4.1                 0
# 326   30               19       76.342105             4.6                 0
#
#      Days Since Last Purchase
# 157                        13
# 341                        36
# 315                        61
# 234                        14
# 155                        23
# ..                        ...
# 94                         47
# 181                        15
# 179                        18
# 199                        17
# 326                        14
#
# [70 rows x 6 columns]

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 0.006847999428607417
# R^2 Score: 0.9929446599663212

# %% [markdown]
# # Buat Model Prediksi (Age, Items Purchased, Spend per Item, Average Rating, Discount Applied, Days Since Last Purchase)

# %%
input_data = [[29, 14, 80.014, 4.6, 1, 25]]
satisfaction_level = model.predict(input_data)

predicted_class = int(round(satisfaction_level[0]))
predicted_class = max(0, min(predicted_class, 2))

satisfaction_labels = ["Unsatisfied", "Neutral", "Satisfied"]
predicted_label = satisfaction_labels[predicted_class]

print(f'Predicted Satisfaction Level: {predicted_label}')
# Out:
# Predicted Satisfaction Level: Satisfied

# %% [markdown]
# # Deployment. Save the trained model

# %%
import pickle

# %%
filename = 'satisfaction_model_sav'
pickle.dump(model, open(filename,'wb'))
